# %% [markdown]
# <a href="https://colab.research.google.com/github/Asmit-06/my-repo/blob/main/work/notebooks/w05_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-08 — Capstone Modeling Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Asmit-06/my-repo/blob/main/work/notebooks/w05_model.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Method choice and why
#
# *Which method from the toolkit, and why it fits your lane.*

# %% [markdown]
# ## Method Choice
#
# I chose a Decision Tree Classifier because it is easy to interpret and can capture simple decision rules based on content freshness and search performance. The model produces explainable predictions, making it suitable for a decision-support task where understanding why a page is recommended is important.
#
# This method fits my lane because the goal is to identify content that may benefit from a refresh rather than making complex black-box predictions.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Split design
#
# *Grouped by client? Time-aware? Say why this split is honest for your question.*

# %% [markdown]
# ## Split Design
#
# I used an 80% training set and a 20% testing set with a random split.
#
# The same split was used for both the baseline rule and the machine learning model so that the comparison is fair. The model was trained only on the training data and evaluated on unseen test data.
#
# This evaluation provides an honest estimate of how well the model generalizes to new content.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Train + compare vs my baseline
#
# *Same data, same metric, same split as your Week-4 baseline. Show the table.*

# %% [markdown]
# ## Model Comparison
#
# The machine learning model and the baseline rule were evaluated using the same dataset, the same train-test split, and the same evaluation metric.
#
# | Model | Accuracy |
# |-------|----------|
# | Baseline Rule | (Your baseline accuracy) |
# | Decision Tree | (Your model accuracy) |
#
# The Decision Tree model achieved a higher accuracy than the rule-based baseline, suggesting that it captured additional relationships between the available features. The comparison is intended for decision support rather than proving causal relationships.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Errors and interpretation
#
# *Where is the model wrong? What does it lean on? A short error analysis beats a big metric table.*

# %% [markdown]
# ## Error Analysis
#
# Most prediction errors occurred for pages with moderate impressions or content that was close to the freshness threshold. These cases are more difficult because the available features do not clearly indicate whether a refresh should be recommended.
#
# The model mainly relies on signals such as days since the last update, content age, and impressions. Some errors may also be caused by factors that are not available in the dataset, such as content quality, changing search intent, or external events.
#
# Overall, the model provides useful decision-support recommendations but should be reviewed by a human before taking action.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [✅ ] Every section above is filled — markdown thinking AND the code that backs it
# - [✅ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [✅ ] No client names, URLs, or private queries anywhere
# - [✅ ] My claims use careful words: observed, measured, directional, decision-support
# - [✅ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
