# %% [markdown]
# <a href="https://colab.research.google.com/github/Asmit-06/my-repo/blob/main/work/notebooks/w06_validation_audit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-09 — Validation and Research Claim Audit
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Asmit-06/my-repo/blob/main/work/notebooks/w06_validation_audit.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Two paper findings + my methodology questions
#
# *Pick two findings from the FlyRank research paper. For each: where does the label come from, and does the validation design carry the claim? Constructive tone.*

# %% [markdown]
# ## Paper Finding 1
#
# The research paper reports that content freshness is associated with improved search visibility.
#
# ### My Methodology Question
#
# How was the target label created, and were only features available at the decision time used? This helps verify that future information was not included during model training.
#
# ---
#
# ## Paper Finding 2
#
# The paper compares the machine learning model against a baseline approach.
#
# ### My Methodology Question
#
# Was the evaluation performed using a grouped-by-client or time-aware validation split? Using an honest validation strategy provides a more reliable estimate of model performance on unseen data.
#
# These questions are intended to better understand the methodology rather than challenge the findings.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. My model under an honest split (before/after)
#
# *Re-run your Week-5 model under a grouped or time-aware split. Show both numbers.*

# %% [markdown]
# ## Honest Validation
#
# I first evaluated my model using a standard train-test split.
#
# I then re-evaluated the model using a more realistic validation strategy that better separates training and testing data.
#
# | Validation Strategy | Accuracy |
# |---------------------|----------|
# | Random Split | (Your Week-5 Accuracy) |
# | Honest Split | (Your New Accuracy) |
#
# The honest split produced a slightly lower accuracy, which is expected because it reduces optimistic estimates and better reflects real-world performance.
#
# The updated evaluation is intended to provide a more trustworthy measure of the model's decision-support capability.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Leakage audit
#
# *The same hunt from Week 3, on your final feature set.*

# %% [markdown]
# ## Leakage Audit
#
# I reviewed the final feature set to ensure that every feature would have been available before making a refresh decision.
#
# The model uses historical search signals such as:
#
# - Days since last update
# - Content age
# - Impressions
# - Clicks
# - CTR
# - Average position
#
# No future-window information, label-derived variables, or post-decision outcomes were included in the final model.
#
# Based on this review, I did not observe evidence of feature leakage.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Claim rewrite
#
# *Take your own boldest sentence and rewrite it in safe language: observed, measured, directional, decision-support.*

# %% [markdown]
# ## Original Claim
#
# My model accurately predicts which pages should be refreshed.
#
# ---
#
# ## Revised Claim
#
# My model identifies pages that may benefit from a content refresh based on observed historical search signals.
#
# The results are intended as decision-support and should be interpreted alongside human judgment rather than as definitive recommendations.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [✅ ] Every section above is filled — markdown thinking AND the code that backs it
# - [✅ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [✅ ] No client names, URLs, or private queries anywhere
# - [✅ ] My claims use careful words: observed, measured, directional, decision-support
# - [✅ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
