# %% [markdown]
# <a href="https://colab.research.google.com/github/Asmit-06/my-repo/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Asmit-06/my-repo/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ## My Lane
#
# I chose the Content Refresh Prioritization lane because it focuses on identifying pages that are likely to decline in performance and should be refreshed first. This problem is useful because content teams often have limited time and resources, so prioritizing the right pages can improve efficiency. My goal is to explore patterns in the data that can help support better content refresh decisions.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ## Research Question
#
# **Decision:** Which pages should be prioritized for content refresh?
#
# **Action:** A content or SEO team can refresh the highest priority pages first.
#
# **Cost of a wrong recommendation:** Refreshing the wrong pages wastes time and resources, while important declining pages may continue losing traffic and visibility.
#
# This project aims to provide decision support using the available data rather than replacing human judgment.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# ## Quick Look at the Data
#
# The following code loads the starter dataset and summarizes a few basic statistics to understand its structure and why this problem is worth investigating.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Total pages:", len(df))
print("\nTrend distribution:")
print(df["trend_direction"].value_counts())

print("\nAverage CTR:", round(df["ctr"].mean(), 4))
print("Median Word Count:", int(df["word_count"].median()))
# Out:
# Total pages: 30000
#
# Trend distribution:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64
#
# Average CTR: 0.5107
# Median Word Count: 2877

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# ## Careful Words
#
# This work is intended to provide decision support based on observed patterns in the available data. Any findings will be interpreted as directional rather than causal. The project does not attempt to predict Google's ranking algorithm or prove cause-and-effect relationships. Instead, it aims to help prioritize content refresh decisions using measurable evidence.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ✅ ] Every section above is filled — markdown thinking AND the code that backs it
# - [✅ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [✅ ] No client names, URLs, or private queries anywhere
# - [✅ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ✅] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
